# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd


# In[10]:


# Read the CSV file with specified data types
food = pd.read_csv("en.openfoodfacts.org.products.tsv",sep='\t')
# Print the DataFrame
print(food)


# In[11]:


# Display the first 5 entries
print(food.head())


# In[12]:


#What is the number of observations in the dataset?
num_observations = food.shape[0]
print(f'Number of observations: {num_observations}')


# In[13]:


#What is the number of columns in the dataset?
num_columns = food.shape[1]
print(f'Number of columns: {num_columns}')


# In[15]:


column_name_105 = food.columns[104]  # Note: Python uses 0-based indexing
print(f'Name of the 105th column: {column_name_105}')


# In[16]:


# Get the data type of the 105th column
column_dtype_105 = food.dtypes[104]  # Note: Python uses 0-based indexing
print(f'Type of the observations in the 105th column: {column_dtype_105}')


# In[17]:


current_index = food.index
print(f'Current index of the DataFrame: {current_index}')


# In[18]:


product_name_19th = food.loc[18, 'product_name']  # Note: Python uses 0-based indexing
print(f'Product name of the 19th observation: {product_name_19th}')


# In[ ]:
